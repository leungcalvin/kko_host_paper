# %% [markdown]
# # use local_universe branch of FRBs repo

# %% [markdown]
# `HEAD is now at c3405c4b 3d catalog matching`

# %%
# %pdb on

import importlib
from frb.surveys import cluster_search
importlib.reload(cluster_search)
import astropy.coordinates as ac
import astropy.units as u
import pandas as pd
import numpy as np

cat = pd.read_csv('/arc/home/calvin/kko_host_paper/data_products/remove_clusters_lowdm_edgeon.csv')
cat.set_index('name',inplace=True)
#hg = ac.SkyCoord(ra = '12h27m0s', dec = '12d43m0s')
#for survey in [cluster_search.TullyGroupCat,
#               cluster_search.WenGroupCat,
#               cluster_search.UPClusterSZCat,
#               cluster_search.TempelClusterCat,
#               #cluster_search.ROSATXClusterCat
#              ]:
#    print('Checking',survey)
#    a = survey(coord = hg, radius = 3 * u.deg)
#    ans = a._get_catalog()
#    print(ans)


def get_ac_from_row(host):
    if str(host['ra_frb']) == 'nan':
        hra = host['frb_ra']
        hdec = host['frb_dec']
    elif str(host['frb_ra']) == 'nan':
        hra = host['ra_frb']
        hdec = host['dec_frb']
    try:
        ra = float(hra)
        dec = float(hdec)
    except ValueError:
        if ':' in hra or 'h' in hra:
            hh,mm,ss =hra.split(':')
            ra = 15 * float(int(hh) + (int(mm) / 60) + (float(ss) / 3600))
        if ':' in hdec or 'h' in hdec:
            dd,mm,ss = hdec.split(':')
            dec = float(int(dd) + (int(mm) / 60) + (float(ss) / 3600))

    return ac.SkyCoord(ra = ra * u.deg, dec = dec * u.deg)

from frb.surveys import survey_utils as su
importlib.reload(su)

import matplotlib.pyplot as plt
# Out:
# Automatic pdb calling has been turned ON
# Warning:  You need FRB/pulsars installed to use PSRCat

# %% [markdown]
# # Initial Search

# %%
for zoom in [1,30]:
    for survey, radius in [
       [cluster_search.TullyGroupCat, 3 * u.degree],
       [cluster_search.WenGroupCat, 2 * u.degree],
       [cluster_search.UPClusterSZCat, 50 * u.degree],
       [cluster_search.TempelClusterCat, 50 * u.degree],
       [cluster_search.ROSATXClusterCat, 50 * u.degree]
                      ]:
        hits = 0
        f,axs = plt.subplots(nrows = 4, ncols = 5,figsize = (12,8))
        iiax = 0
        f.suptitle(survey)
        for iihost, host in cat.iterrows():
            hg = get_ac_from_row(host)
            aa = survey(coord = hg, radius = radius/zoom + 4 * u.arcmin)
            big_cat = aa.get_catalog()
            print('Checking',host.name,'in',survey)
            axs.flat[iiax].scatter(big_cat['ra'],big_cat['dec'])
            axs.flat[iiax].scatter(hg.ra,hg.dec)
            axs.flat[iiax].set_title(iihost)
            iiax += 1
            print(iihost,'at',host['primary_z_spec'])
            big_cat['transv_dist'] = ((host['primary_dec']**2 * (big_cat['ra'] - host['primary_ra']))**2 + (big_cat['dec'] - host['primary_dec'])**2)**0.5
            big_cat = big_cat.sort('transv_dist')
            print(big_cat)

        f.tight_layout()
# Out:
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20200430A at 0.1608
# None
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20211127I at 0.0469
# None
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20211212A at 0.0715
# None
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20210807D at 0.1293
# None
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20220912A at 0.0771
# None
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20220725A at 0.1926
# None
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20230526A at 0.157
# None
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231226A at 0.1569
# None
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20240210A at 0.023686
# None
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20220920A at 0.158239
# None
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20230628A at 0.1265
# None
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20230222B at 0.11
# None
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20230926A at 0.0553
# None
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231011A at 0.0783
# None
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231123A at 0.0729
# None
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231128A at 0.1079
# None
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231201A at 0.119
# None
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231223C at 0.1059
# None
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231229A at 0.019
# None
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231230A at 0.02981
# None
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20200430A at 0.1608
# None
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20211127I at 0.0469
# None
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20211212A at 0.0715
# None
# No objects found within the given radius.
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20210807D at 0.1293
# None
# No objects found within the given radius.
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20220912A at 0.0771
# None
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20220725A at 0.1926
# None
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20230526A at 0.157
# None
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231226A at 0.1569
# None
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20240210A at 0.023686
# None
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20220920A at 0.158239
# None
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20230628A at 0.1265
# None
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20230222B at 0.11
# None
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20230926A at 0.0553
# None
# No objects found within the given radius.
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231011A at 0.0783
# None
# No objects found within the given radius.
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231123A at 0.0729
# None
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231128A at 0.1079
# None
# No objects found within the given radius.
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231201A at 0.119
# None
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231223C at 0.1059
# None
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231229A at 0.019
# None
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231230A at 0.02981
# None
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20200430A at 0.1608
# None
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20211127I at 0.0469
# None
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20211212A at 0.0715
# None
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20210807D at 0.1293
# None
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20220912A at 0.0771
# None
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20220725A at 0.1926
# None
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20230526A at 0.157
# None
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231226A at 0.1569
# None
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20240210A at 0.023686
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# None
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20220920A at 0.158239
# None
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20230628A at 0.1265
# None
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20230222B at 0.11
# None
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20230926A at 0.0553
# None
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231011A at 0.0783
# None
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231123A at 0.0729
# None
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231128A at 0.1079
# None
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231201A at 0.119
# None
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231223C at 0.1059
# None
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231229A at 0.019
# None
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231230A at 0.02981
# None
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20200430A at 0.1608
# None
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20211127I at 0.0469
# None
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20211212A at 0.0715
# None
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20210807D at 0.1293
# None
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20220912A at 0.0771
# None
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20220725A at 0.1926
# None
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20230526A at 0.157
# None
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231226A at 0.1569
# None
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20240210A at 0.023686
# None
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20220920A at 0.158239
# None
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20230628A at 0.1265
# None
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20230222B at 0.11
# None
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20230926A at 0.0553
# None
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231011A at 0.0783
# None
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231123A at 0.0729
# None
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231128A at 0.1079
# None
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231201A at 0.119
# None
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231223C at 0.1059
# None
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231229A at 0.019
# None
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231230A at 0.02981
# None
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20200430A at 0.1608
# None
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20211127I at 0.0469
# None
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20211212A at 0.0715
# None
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20210807D at 0.1293
# None
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20220912A at 0.0771
# None
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20220725A at 0.1926
# None
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20230526A at 0.157
# None
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231226A at 0.1569
# None
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20240210A at 0.023686
# None
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20220920A at 0.158239
# None
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20230628A at 0.1265
# None
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20230222B at 0.11
# None
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20230926A at 0.0553
# None
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231011A at 0.0783
# None
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231123A at 0.0729
# None
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231128A at 0.1079
# None
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231201A at 0.119
# None
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231223C at 0.1059
# None
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231229A at 0.019
# None
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231230A at 0.02981
# None
# No objects found within the given radius.
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20200430A at 0.1608
# None
# No objects found within the given radius.
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20211127I at 0.0469
# None
# No objects found within the given radius.
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20211212A at 0.0715
# None
# No objects found within the given radius.
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20210807D at 0.1293
# None
# No objects found within the given radius.
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20220912A at 0.0771
# None
# No objects found within the given radius.
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20220725A at 0.1926
# None
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20230526A at 0.157
# None
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231226A at 0.1569
# None
# No objects found within the given radius.
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20240210A at 0.023686
# None
# No objects found within the given radius.
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20220920A at 0.158239
# None
# No objects found within the given radius.
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20230628A at 0.1265
# None
# No objects found within the given radius.
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20230222B at 0.11
# None
# No objects found within the given radius.
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20230926A at 0.0553
# None
# No objects found within the given radius.
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231011A at 0.0783
# None
# No objects found within the given radius.
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231123A at 0.0729
# None
# No objects found within the given radius.
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231128A at 0.1079
# None
# No objects found within the given radius.
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231201A at 0.119
# None
# No objects found within the given radius.
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231223C at 0.1059
# None
# No objects found within the given radius.
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231229A at 0.019
# None
# No objects found within the given radius.
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231230A at 0.02981
# None
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20200430A at 0.1608
# None
# No objects found within the given radius.
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20211127I at 0.0469
# None
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20211212A at 0.0715
# None
# No objects found within the given radius.
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20210807D at 0.1293
# None
# No objects found within the given radius.
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20220912A at 0.0771
# None
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20220725A at 0.1926
# None
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20230526A at 0.157
# None
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231226A at 0.1569
# None
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20240210A at 0.023686
# None
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20220920A at 0.158239
# None
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20230628A at 0.1265
# None
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20230222B at 0.11
# None
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20230926A at 0.0553
# None
# No objects found within the given radius.
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231011A at 0.0783
# None
# No objects found within the given radius.
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231123A at 0.0729
# None
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231128A at 0.1079
# None
# No objects found within the given radius.
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231201A at 0.119
# None
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231223C at 0.1059
# None
# No objects found within the given radius.
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231229A at 0.019
# None
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231230A at 0.02981
# None
# No objects found within the given radius.
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20200430A at 0.1608
# None
# No objects found within the given radius.
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20211127I at 0.0469
# None
# No objects found within the given radius.
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20211212A at 0.0715
# None
# No objects found within the given radius.
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20210807D at 0.1293
# None
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20220912A at 0.0771
# None
# No objects found within the given radius.
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20220725A at 0.1926
# None
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# No objects found within the given radius.
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20230526A at 0.157
# None
# No objects found within the given radius.
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231226A at 0.1569
# None
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20240210A at 0.023686
# None
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20220920A at 0.158239
# None
# No objects found within the given radius.
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20230628A at 0.1265
# None
# No objects found within the given radius.
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20230222B at 0.11
# None
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20230926A at 0.0553
# None
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231011A at 0.0783
# None
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231123A at 0.0729
# None
# No objects found within the given radius.
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231128A at 0.1079
# None
# No objects found within the given radius.
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231201A at 0.119
# None
# No objects found within the given radius.
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231223C at 0.1059
# None
# No objects found within the given radius.
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231229A at 0.019
# None
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231230A at 0.02981
# None
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20200430A at 0.1608
# None
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20211127I at 0.0469
# None
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20211212A at 0.0715
# None
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20210807D at 0.1293
# None
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20220912A at 0.0771
# None
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20220725A at 0.1926
# None
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20230526A at 0.157
# None
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231226A at 0.1569
# None
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20240210A at 0.023686
# None
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20220920A at 0.158239
# None
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20230628A at 0.1265
# None
# No objects found within the given radius.
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20230222B at 0.11
# None
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20230926A at 0.0553
# None
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231011A at 0.0783
# None
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231123A at 0.0729
# None
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231128A at 0.1079
# None
# No objects found within the given radius.
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231201A at 0.119
# None
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231223C at 0.1059
# None
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231229A at 0.019
# None
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231230A at 0.02981
# None
# No objects found within the given radius.
# Checking FRB20200430A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20200430A at 0.1608
# None
# No objects found within the given radius.
# Checking FRB20211127I in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20211127I at 0.0469
# None
# Checking FRB20211212A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20211212A at 0.0715
# None
# No objects found within the given radius.
# Checking FRB20210807D in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20210807D at 0.1293
# None
# No objects found within the given radius.
# Checking FRB20220912A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20220912A at 0.0771
# None
# No objects found within the given radius.
# Checking FRB20220725A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20220725A at 0.1926
# None
# No objects found within the given radius.
# Checking FRB20230526A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20230526A at 0.157
# None
# No objects found within the given radius.
# Checking FRB20231226A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231226A at 0.1569
# None
# No objects found within the given radius.
# Checking FRB20240210A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20240210A at 0.023686
# None
# No objects found within the given radius.
# Checking FRB20220920A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20220920A at 0.158239
# None
# No objects found within the given radius.
# Checking FRB20230628A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20230628A at 0.1265
# None
# No objects found within the given radius.
# Checking FRB20230222B in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20230222B at 0.11
# None
# Checking FRB20230926A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20230926A at 0.0553
# None
# Checking FRB20231011A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231011A at 0.0783
# None
# No objects found within the given radius.
# Checking FRB20231123A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231123A at 0.0729
# None
# No objects found within the given radius.
# Checking FRB20231128A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231128A at 0.1079
# None
# No objects found within the given radius.
# Checking FRB20231201A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231201A at 0.119
# None
# No objects found within the given radius.
# Checking FRB20231223C in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231223C at 0.1059
# None
# No objects found within the given radius.
# Checking FRB20231229A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231229A at 0.019
# None
# Checking FRB20231230A in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231230A at 0.02981
# None
# Error in callback <function flush_figures at 0x7fd30d73d4c0> (for post_execute):
# KeyboardInterrupt

# %%
hg = ac.SkyCoord(ra = '19h39m05.8925s', dec='59d19m36.8282s')

# %%
aa.get_catalog()
# Out:
# No objects found within the given radius.
# <Table length=0>
#    ra     dec      z
# float64 float64 float64
# ------- ------- -------

# %%
all_cats = []
for zoom in [1,30]:
    for survey, radius in [
       [cluster_search.TullyGroupCat, 3 * u.degree],
       [cluster_search.WenGroupCat, 2 * u.degree],
       [cluster_search.UPClusterSZCat, 50 * u.degree],
       [cluster_search.TempelClusterCat, 50 * u.degree],
       [cluster_search.ROSATXClusterCat, 50 * u.degree]
                      ]:
        hits = 0
        f,axs = plt.subplots(nrows = 4, ncols = 5,figsize = (12,8))
        iiax = 0
        f.suptitle(survey)
        aa = survey(coord = hg, radius = radius/zoom + 4 * u.arcmin)
        big_cat = aa.get_catalog()
        print('Checking','new FRB','in',survey)
        axs.flat[iiax].scatter(big_cat['ra'],big_cat['dec'])
        axs.flat[iiax].scatter(hg.ra,hg.dec)
        axs.flat[iiax].set_title('Meerkat/EVN FRB')
        iiax += 1
        print(iihost,'at',host['primary_z_spec'])
        big_cat['transv_dist'] = ((np.cos(np.deg2rad(hg.dec.degree)) * (big_cat['ra'] - hg.ra.degree))**2 + 
                                  (big_cat['dec'] - hg.dec.degree)**2)**0.5
        big_cat.sort('transv_dist')
        all_cats.append(big_cat)
        f.tight_layout()
# Out:
# Checking new FRB in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231230A at 0.02981
# Checking new FRB in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231230A at 0.02981
# /opt/pysetup/.venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2411: RuntimeWarning: invalid value encountered in _integral_lookback_time (vectorized)
#   outputs = ufunc(*inputs)
# Checking new FRB in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231230A at 0.02981
# Checking new FRB in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231230A at 0.02981
# Checking new FRB in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231230A at 0.02981
# No objects found within the given radius.
# Checking new FRB in <class 'frb.surveys.cluster_search.TullyGroupCat'>
# FRB20231230A at 0.02981
# Checking new FRB in <class 'frb.surveys.cluster_search.WenGroupCat'>
# FRB20231230A at 0.02981
# No objects found within the given radius.
# Checking new FRB in <class 'frb.surveys.cluster_search.UPClusterSZCat'>
# FRB20231230A at 0.02981
# Checking new FRB in <class 'frb.surveys.cluster_search.TempelClusterCat'>
# FRB20231230A at 0.02981
# No objects found within the given radius.
# Checking new FRB in <class 'frb.surveys.cluster_search.ROSATXClusterCat'>
# FRB20231230A at 0.02981

# %%
all_cats
# Out:
# [<Table length=0>
#     _r   recno  PGC  LEDA   GLON  ...   SGZ   Simbad    ra     dec   transv_dist
#                             deg   ...   Mpc            deg     deg
#  float64 int32 int32 str4 float64 ... float32  str6  float64 float64   float64
#  ------- ----- ----- ---- ------- ... ------- ------ ------- ------- -----------,
#  <Table length=425>
#     _r     recno     ID   ...  Cat          Dist            transv_dist
#                           ...
#  float64   int32   int32  ...  str9       float64             float64
#  -------- ------- ------- ... ------ ------------------ -------------------
#  0.095482 1492434 1492434 ... CFSFDP  1970.124143313621 0.09544208133298597
#  0.104476 1492439 1492439 ...        2236.6104803544968 0.10453881692533921
#  0.175266 1492425 1492425 ... CFSFDP  2170.657022107215  0.1751323575045587
#  0.189646 1492541 1492541 ...         1935.311632377082 0.18971964878595796
#  0.213608 1492525 1492525 ...          1297.30440520711   0.213869240686813
#  0.218720 1492505 1492505 ...        1874.3740466085503 0.21889675646486953
#  0.239350 1492363 1492363 ...        2370.4999757720416 0.23958764932599996
#  0.239828 1492510 1492510 ...         2228.546980842278 0.24005199531430818
#  0.246324 1492431 1492431 ... CFSFDP 1608.3401467878282  0.2461957930707141
#       ...     ...     ... ...    ...                ...                 ...
#  2.016618 1492335 1492335 ...         716.6067812746888   2.017819623817738
#  2.002608 1491657 1491657 ...         2136.246168797654   2.026036576655385
#  2.018081 1492878 1492878 ...        1588.2395485674479   2.032830945672591
#  2.047958 1491449 1491449 ...  WHY18 1377.9835704707316  2.0332209722229058
#  2.062054 1491541 1491541 ... CFSFDP 1403.9839797607935   2.039860045494235
#  2.040221 1492506 1492506 ...        1891.0997370893438  2.0404577473953958
#  2.062689 1491410 1491410 ... CFSFDP  2103.848467771629  2.0542545453825607
#  2.057348 1492546 1492546 ...    WHL 1831.2697743931615   2.057955339423207
#  2.059958 1491394 1491394 ...        1534.6557307210185   2.063159809814041
#  2.057513 1491400 1491400 ... CFSFDP  2091.357063319887  2.0659766261708246,
#  <Table length=309>
#     _r    recno  Seq  ... NED         Dist           transv_dist
#                       ...
#  float64  int32 int16 ... str3      float64            float64
#  -------- ----- ----- ... ---- ------------------ ------------------
#   3.27230   418   418 ...  NED                0.0 3.2459829303684944
#   3.61859   420   420 ...  NED 1691.1550423668832  3.696780175582584
#   4.03191   442   442 ...  NED 1081.7906522465776  4.114427463567092
#   4.35868   429   429 ...  NED                0.0  4.394185348633662
#   4.83142   441   441 ...  NED  484.3384877277959  4.961441960751816
#   5.15481   384   384 ...  NED  962.2217081385804  5.154619234719241
#   6.56474   392   392 ...  NED 448.25262760416433  6.398005800973166
#   6.54610   459   459 ...  NED  915.6849654648126  6.552752929761157
#   7.03713   373   373 ...  NED 1268.2450671872125  6.800153188940306
#       ...   ...   ... ...  ...                ...                ...
#  45.26864   631   631 ...  NED                0.0 140.40707975011316
#  30.73691   603   603 ...  NED  2369.188104807788 140.45739384886423
#  42.48807   615   615 ...  NED  437.6348317185002 141.80869314189957
#  49.48806   620   620 ...  NED  733.2503403418598 142.67788732381902
#  42.16973   605   605 ...  NED  439.1542418775144 143.46630953660045
#  40.62660   582   582 ...  NED  1016.828416753144 147.48477559578487
#  30.15929   600   600 ...  NED                0.0   147.825001774496
#  37.02519   572   572 ...  NED  427.7376207706594 149.05591812916597
#  44.49085   555   555 ...  NED  610.7749818063454  150.3266759945225
#  37.23177   557   557 ...  NED  861.7787966970071 150.45687671116278,
#  <Table length=1028>
#      _r    recno GroupID  Ngal ... Simbad        Dist           transv_dist
#                                ...
#   float64  int32  int16  int16 ...  str6       float64            float64
#  --------- ----- ------- ----- ... ------ ------------------ ------------------
#   1.211575  6568    6568     2 ... Simbad  49.30799778794906 1.2196780040188564
#   2.756416  6517    6517     2 ... Simbad 168.26782819167377   2.76783806857086
#   3.033897  6509    6509     2 ... Simbad 105.65066453002797   3.01036841590239
#   3.095600  6558    6558     2 ... Simbad  50.26675345679188  3.090309172184723
#   3.182116  6481    6481     2 ... Simbad  169.3558914440369 3.2255291915967277
#   3.656174  6655    6655     2 ... Simbad  165.0011794971795 3.6697119371054576
#   4.818036  6551    6551     2 ... Simbad  83.15595894334031  4.823834522083276
#   5.341682  6521    6521     2 ... Simbad 55.577900523117975  5.327135728200317
#   5.746018   464     464     3 ... Simbad 276.52807678293556 5.7628559164069175
#        ...   ...     ...   ... ...    ...                ...                ...
#  48.439662   121     121     3 ... Simbad 154.80061943797529  149.0813654722716
#  36.317706   632     632     2 ... Simbad 136.02716550513054  149.3007961166565
#  28.494787   105     105     2 ... Simbad  155.7676441962974 149.82552937490667
#  40.123216    59      59     2 ... Simbad  76.25305443774096  149.9382555725466
#  35.226921   624     624     4 ... Simbad 166.09047240665606 150.11559787329108
#  36.521303    32      32     4 ... Simbad   189.993042889772 150.13478384324915
#  35.202764   628     628     2 ... Simbad  180.5891596634532 150.46643664888504
#  39.216063    37      37     2 ... Simbad  76.64177036215823 150.46730620994205
#  48.462683    11      11     2 ... Simbad 182.08918214633704  152.2404370662827
#  49.848804     7       7     4 ... Simbad 146.33592815293923 152.68234569216227,
#  <Table length=214>
#     _r   recno RXGCC    ra   ... SimbadName        Dist        transv_dist
#                        deg   ...
#  float64 int32 int16 float32 ...    str9         float64         float32
#  ------- ----- ----- ------- ... ---------- ------------------ -----------
#   4.5595   802   802 290.035 ...  RXGCC 802 315.62203649145766    4.634744
#   6.5163   796   796 283.049 ...  RXGCC 796  419.3344895961797    6.350557
#   6.6510   805   805 291.871 ...             731.8959282500452   6.6833134
#   7.6127   789   789 279.730 ...  RXGCC 789  292.0791630429446    7.752836
#   7.5507   798   798 284.499 ...  RXGCC 798  320.7827560648181    7.867731
#   8.2586   808   808 293.831 ...             667.3821474136167    8.262135
#   8.2405   804   804 291.136 ...  RXGCC 804 308.85889509706874    8.291537
#   7.9629   793   793 282.066 ...  RXGCC 793 306.86659458814324    8.378962
#   8.4393   785   785 278.178 ...  RXGCC 785 378.86456877525455     8.46667
#      ...   ...   ...     ... ...        ...                ...         ...
#  49.0740   513   513 203.176 ...  RXGCC 513 1010.8265280480613    47.54553
#  47.2500   455   455 186.150 ...  RXGCC 455  285.2585525553486   55.459034
#  45.5388   423   423 176.198 ...  RXGCC 423  474.2388413171596    61.02902
#  47.0429   415   415 173.334 ...  RXGCC 415 470.86371059135564   62.352135
#  40.8492   394   394 168.402 ...  RXGCC 394  453.9234210844616   66.451256
#  41.4233   381   381 164.267 ...  RXGCC 381  488.8148675511121    68.51611
#  34.9666   271   271 113.161 ...  RXGCC 271 30.418912437270876    96.33013
#  48.7057   259   259 107.029 ...  RXGCC 259  425.4484559304828   96.592545
#  38.7203   189   189  74.964 ...  RXGCC 189   255.374211155192   114.04774
#  49.2769    33    33  10.536 ...  RXGCC  33   384.683060254749   146.23892,
#  <Table length=0>
#     ra     dec      z    transv_dist
#  float64 float64 float64   float64
#  ------- ------- ------- -----------,
#  <Table length=2>
#     _r     recno     ID   ...  Cat          Dist            transv_dist
#                           ...
#  float64   int32   int32  ...  str9       float64             float64
#  -------- ------- ------- ... ------ ------------------ -------------------
#  0.095482 1492434 1492434 ... CFSFDP  1970.124143313621 0.09544208133298597
#  0.104476 1492439 1492439 ...        2236.6104803544968 0.10453881692533921,
#  <Table length=0>
#     ra     dec      z    transv_dist
#  float64 float64 float64   float64
#  ------- ------- ------- -----------,
#  <Table length=1>
#     _r    recno GroupID  Ngal ... Simbad        Dist          transv_dist
#                               ...
#  float64  int32  int16  int16 ...  str6       float64           float64
#  -------- ----- ------- ----- ... ------ ----------------- ------------------
#  1.211575  6568    6568     2 ... Simbad 49.30799778794906 1.2196780040188564,
#  <Table length=0>
#     ra     dec      z    transv_dist
#  float64 float64 float64   float64
#  ------- ------- ------- -----------]

# %%
row
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 row
#
# NameError: name 'row' is not defined
# > /tmp/ipykernel_2379/2323360758.py(1)<module>()
# ----> 1 row
# ipdb>  q

# %%
row
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 row
#
# NameError: name 'row' is not defined
# > /tmp/ipykernel_2379/2323360758.py(1)<module>()
# ----> 1 row
# ipdb>  q

# %%
plotcat.iterrows()

# %%
row
# Out:
# <Row index=0>
#    _r     recno     ID   n_Name       Name           ra       dec       z    f_zCl   zmag   W1mag   logMs    r500   lam500      M500      Ngal  Gamma  e_Gamma imag_  Cat          Dist           transv_dist
#                                                     deg       deg                    mag     mag   solMass   Mpc           1e+14 solMass
# float64   int32   int32   str3       str16        float64   float64  float32 uint8 float32 float32 float32 float32 float32    float32    int16 float32 float32 uint8  str9       float64            float64
# -------- ------- ------- ------ ---------------- --------- --------- ------- ----- ------- ------- ------- ------- ------- ------------- ----- ------- ------- ----- ------ ------------------ ------------------
# 1.054605 1492305 1492305        J193617.7+582012 294.07394  58.33658  0.0993     0  14.465  14.682   11.44   0.729   22.96          1.05    14      --      --     2 CFSFDP 409.75351861238835 1.0528384980919188

# %%
from astropy.cosmology import Planck18

# %%
row
# Out:
# <Row index=0>
#    _r     recno     ID   n_Name       Name           ra       dec       z    f_zCl   zmag   W1mag   logMs    r500   lam500      M500      Ngal  Gamma  e_Gamma imag_  Cat          Dist           transv_dist
#                                                     deg       deg                    mag     mag   solMass   Mpc           1e+14 solMass
# float64   int32   int32   str3       str16        float64   float64  float32 uint8 float32 float32 float32 float32 float32    float32    int16 float32 float32 uint8  str9       float64            float64
# -------- ------- ------- ------ ---------------- --------- --------- ------- ----- ------- ------- ------- ------- ------- ------------- ----- ------- ------- ----- ------ ------------------ ------------------
# 1.054605 1492305 1492305        J193617.7+582012 294.07394  58.33658  0.0993     0  14.465  14.682   11.44   0.729   22.96          1.05    14      --      --     2 CFSFDP 409.75351861238835 1.0528384980919188

# %%
from astropy.cosmology import Planck18
from matplotlib.patches import Circle

# %%
hg.ra.degree
# Out:
# 294.7745520833333

# %%
angular_radius
# Out:
# <Quantity 4.62045381e-05 deg>

# %%
row['r500']
# Out:
# 0.531

# %%
plt.figure()
for iicat,cat in enumerate(all_cats[0:4]):
    plotcat = cat
    try:
        cat = cat[cat['z'] < 0.25]
    plt.scatter(plotcat['ra'],plotcat['dec'],marker = 'x')
    plt.scatter(hg.ra.degree,hg.dec.degree,color = f'C{iicat}',label = f'{iicat}')
    ax = plt.gca()
    for row in plotcat:
        # Calculate angular diameter distance
        ang_diam_dist = Planck18.angular_diameter_distance(row['z']).to(u.Mpc).value

        # Convert r200 to angular radius (assuming r200 is in kpc or Mpc)
        # Adjust the unit conversion as needed for your r200 units
        angular_radius = np.rad2deg(row['r500'] / ang_diam_dist) * (1/0.7) * 2

        # Create circle (radius in arcsec, converted to degrees for plotting)
        circle = Circle((row['ra'], row['dec']), 
                       angular_radius,  # convert arcsec to degrees
                       fill=False, edgecolor=f'C{iicat}', linewidth=1)
        ax.add_patch(circle)
        ax.text(row['ra'], row['dec'], f'z={row["z"]:.3f}', 
                ha='left', va='center', fontsize=8)

    ax.set_xlabel('RA (degrees)')
    ax.set_ylabel('Dec (degrees)')
    ax.set_aspect('equal')
    ax.grid(True, alpha=0.3)
    plt.title('Wen+Han catalog')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 3
#       1 plt.figure()
#       2 for iicat,cat in enumerate(all_cats[0:4]):
# ----> 3     plotcat = cat[cat['z'] < 0.25]
#       4     plt.scatter(plotcat['ra'],plotcat['dec'],marker = 'x')
#       5     plt.scatter(hg.ra.degree,hg.dec.degree,color = f'C{iicat}',label = f'{iicat}')
#
# File /opt/pysetup/.venv/lib/python3.8/site-packages/astropy/table/table.py:2075, in Table.__getitem__(self, item)
#    2073 def __getitem__(self, item):
#    2074     if isinstance(item, str):
# -> 2075         return self.columns[item]
#    2076     elif isinstance(item, (int, np.integer)):
#    2077         return self.Row(self, item)
#
# File /opt/pysetup/.venv/lib/python3.8/site-packages/astropy/table/table.py:263, in TableColumns.__getitem__(self, item)
#     253 """Get items from a TableColumns object.
#     254 ::
#     255
#    (...)
#     260   tc[1:3] # <TableColumns names=('b', 'c')>
#     261 """
#     262 if isinstance(item, str):
# --> 263     return OrderedDict.__getitem__(self, item)
#     264 elif isinstance(item, (int, np.integer)):
#     265     return list(self.values())[item]
#
# KeyError: 'z'
# > /opt/pysetup/.venv/lib/python3.8/site-packages/astropy/table/table.py(263)__getitem__()
#     261         """
#     262         if isinstance(item, str):
# --> 263             return OrderedDict.__getitem__(self, item)
#     264         elif isinstance(item, (int, np.integer)):
#     265             return list(self.values())[item]
# ipdb>  q

# %%
all_cats[-4][['ra','dec']]
# Out:
# <Table length=2>
#     ra       dec
#    deg       deg
#  float64   float64
# --------- ---------
# 294.59497  59.30013
# 294.60519  59.38575
